# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, classification_report
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE  # for handling class imbalance

# %% [markdown]
# # Feature Engg

# %%
df = pd.read_csv("/content/superstore_data.csv")
df.head(5)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  Response             2240 non-null   int64
#  21  Complain             2240 non-null   int64
# dtypes: float64(1), int64(18), object(3)
# memory usage: 385.1+ KB

# %%
df.drop(['Id', 'Dt_Customer'], axis=1, inplace=True)

# %%
from datetime import datetime

current_year = datetime.now().year
df['Age'] = current_year - df['Year_Birth']

# %%
df.head(5)
# Out:
#    Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  Recency  \
# 0        1970  Graduation       Divorced  84835.0        0         0        0
# 1        1961  Graduation         Single  57091.0        0         0        0
# 2        1958  Graduation        Married  67267.0        0         1        0
# 3        1967  Graduation       Together  32474.0        1         1        0
# 4        1989  Graduation         Single  21474.0        1         0        0
#
#    MntWines  MntFruits  MntMeatProducts  ...  MntSweetProducts  MntGoldProds  \
# 0       189        104              379  ...               189           218
# 1       464          5               64  ...                 0            37
# 2       134         11               59  ...                 2            30
# 3        10          0                1  ...                 0             0
# 4         6         16               24  ...                 0            34
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                  1                4                    4                  6
# 1                  1                7                    3                  7
# 2                  1                3                    2                  5
# 3                  1                1                    0                  2
# 4                  2                3                    1                  2
#
#    NumWebVisitsMonth  Response  Complain  Age
# 0                  1         1         0   55
# 1                  5         1         0   64
# 2                  2         0         0   67
# 3                  7         0         0   58
# 4                  7         1         0   36
#
# [5 rows x 21 columns]

# %%
df.drop( 'Year_Birth', axis=1, inplace=True)

# %%
df.isnull().mean()
# Out:
# Education              0.000000
# Marital_Status         0.000000
# Income                 0.010714
# Kidhome                0.000000
# Teenhome               0.000000
# Recency                0.000000
# MntWines               0.000000
# MntFruits              0.000000
# MntMeatProducts        0.000000
# MntFishProducts        0.000000
# MntSweetProducts       0.000000
# MntGoldProds           0.000000
# NumDealsPurchases      0.000000
# NumWebPurchases        0.000000
# NumCatalogPurchases    0.000000
# NumStorePurchases      0.000000
# NumWebVisitsMonth      0.000000
# Response               0.000000
# Complain               0.000000
# Age                    0.000000
# dtype: float64

# %%
#handling missing data
df = df.dropna()

# %%
#reducing features
df['Family_Size'] = df['Kidhome'] + df['Teenhome']
df.drop(['Kidhome', 'Teenhome'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2216 entries, 0 to 2239
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Education            2216 non-null   object
#  1   Marital_Status       2216 non-null   object
#  2   Income               2216 non-null   float64
#  3   Recency              2216 non-null   int64
#  4   MntWines             2216 non-null   int64
#  5   MntFruits            2216 non-null   int64
#  6   MntMeatProducts      2216 non-null   int64
#  7   MntFishProducts      2216 non-null   int64
#  8   MntSweetProducts     2216 non-null   int64
#  9   MntGoldProds         2216 non-null   int64
#  10  NumDealsPurchases    2216 non-null   int64
#  11  NumWebPurchases      2216 non-null   int64
#  12  NumCatalogPurchases  2216 non-null   int64
#  13  NumStorePurchases    2216 non-null   int64
#  14  NumWebVisitsMonth    2216 non-null   int64
#  15  Response             2216 non-null   int64
#  16  Complain             2216 non-null   int64
#  17  Age                  2216 non-null   int64
#  18  Family_Size          2216 non-null   int64
# dtypes: float64(1), int64(16), object(2)
# memory usage: 346.2+ KB

# %%
df.shape
# Out:
# (2216, 19)

# %% [markdown]
# ## Performing **EDA**

# %% [markdown]
# ### Bar chart

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Melt spending columns into long format
spending_cols = ['MntWines', 'MntMeatProducts', 'MntFruits', 'MntFishProducts', 'MntSweetProducts']
df_melted = df.melt(id_vars='Response', value_vars=spending_cols,
                    var_name='Product', value_name='Spending')

# Plot grouped bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Product', y='Spending', hue='Response', data=df_melted, palette='Set2')
plt.title('Spending by Product Category and Campaign Response')
plt.ylabel('Amount Spent')
plt.xlabel('Product Category')
plt.legend(title='Response')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# reducing features
df['Non_veg'] = df['MntMeatProducts'] + df['MntFishProducts']
df['Fruit_Sweet'] = df['MntSweetProducts'] + df['MntFruits']
df.drop(['MntMeatProducts', 'MntFishProducts'], axis=1, inplace=True)

# %%
df.drop(['MntSweetProducts', 'MntFruits'], axis=1, inplace=True)

# %%
spending_cols = ['MntWines', 'Non_veg','Fruit_Sweet']
df_melted = df.melt(id_vars='Response', value_vars=spending_cols,
                    var_name='Product', value_name='Spending')

# Plot grouped bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Product', y='Spending', hue='Response', data=df_melted, palette='Set2')
plt.title('Spending by Product Category and Campaign Response')
plt.ylabel('Amount Spent')
plt.xlabel('Product Category')
plt.legend(title='Response')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2216 entries, 0 to 2239
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Education            2216 non-null   object
#  1   Marital_Status       2216 non-null   object
#  2   Income               2216 non-null   float64
#  3   Recency              2216 non-null   int64
#  4   MntWines             2216 non-null   int64
#  5   MntGoldProds         2216 non-null   int64
#  6   NumDealsPurchases    2216 non-null   int64
#  7   NumWebPurchases      2216 non-null   int64
#  8   NumCatalogPurchases  2216 non-null   int64
#  9   NumStorePurchases    2216 non-null   int64
#  10  NumWebVisitsMonth    2216 non-null   int64
#  11  Response             2216 non-null   int64
#  12  Complain             2216 non-null   int64
#  13  Age                  2216 non-null   int64
#  14  Family_Size          2216 non-null   int64
#  15  Non_veg              2216 non-null   int64
#  16  Fruit_Sweet          2216 non-null   int64
# dtypes: float64(1), int64(14), object(2)
# memory usage: 311.6+ KB

# %% [markdown]
# ### Box plot

# %%
# outliers detctions
df['Income'].describe()
# Out:
# count      2216.000000
# mean      52247.251354
# std       25173.076661
# min        1730.000000
# 25%       35303.000000
# 50%       51381.500000
# 75%       68522.000000
# max      666666.000000
# Name: Income, dtype: float64

# %%
sns.boxplot(x=df['Income'])
# Out:
# <Axes: xlabel='Income'>

# %%
df_fi = df[df['Income'] > 200000]
df_fi.head()
# Out:
#       Education Marital_Status    Income  Recency  MntWines  MntGoldProds  \
# 527  Graduation       Together  666666.0       23         9            12
#
#      NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 527                  4                3                    1
#
#      NumStorePurchases  NumWebVisitsMonth  Response  Complain  Age  \
# 527                  3                  6         0         0   48
#
#      Family_Size  Non_veg  Fruit_Sweet
# 527            1       26           15

# %%
# REMOVE OUTLIER
df = df.drop(index= 527)

# %%
#we will going to divide the income section into three part which is the small , medium and high earning individuals which can provide us more information on the subscroption part.

# 25% 35284.000000 50% 51373.000000 75% 68487.000000
percentiles = df['Income'].quantile([0.25,0.50,0.75])
percentiles
# Out:
# 0.25    35284.0
# 0.50    51373.0
# 0.75    68487.0
# Name: Income, dtype: float64

# %%
# Function for dividing the income
def income_cat(x):
    if x < percentiles[0.25]:
        return 'low wage earner'
    elif x < percentiles[0.50]:
        return 'medium wage earner'
    else:
        return 'high wage earner'

# %%
df['wage_earner'] = df['Income'].apply(income_cat)

# %%
df.head()
# Out:
#     Education Marital_Status   Income  Recency  MntWines  MntGoldProds  \
# 0  Graduation       Divorced  84835.0        0       189           218
# 1  Graduation         Single  57091.0        0       464            37
# 2  Graduation        Married  67267.0        0       134            30
# 3  Graduation       Together  32474.0        0        10             0
# 4  Graduation         Single  21474.0        0         6            34
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                  1                4                    4                  6
# 1                  1                7                    3                  7
# 2                  1                3                    2                  5
# 3                  1                1                    0                  2
# 4                  2                3                    1                  2
#
#    NumWebVisitsMonth  Response  Complain  Age  Family_Size  Non_veg  \
# 0                  1         1         0   55            0      490
# 1                  5         1         0   64            0       71
# 2                  2         0         0   67            1       74
# 3                  7         0         0   58            2        1
# 4                  7         1         0   36            1       35
#
#    Fruit_Sweet       wage_earner
# 0          293  high wage earner
# 1            5  high wage earner
# 2           13  high wage earner
# 3            0   low wage earner
# 4           16   low wage earner

# %% [markdown]
# ### Capture behavior and **relationships**

# %%
# total_spent: sum of Mnt*
df['total_spent'] = df['MntWines'] + df['Non_veg'] + df['Fruit_Sweet'] + df['MntGoldProds']

# %%
# Online Engagement: Sum of web purchases and visits
df['Online_Engagement'] = df['NumWebPurchases'] + df['NumWebVisitsMonth']

# Offline Engagement: Sum of store and catalog purchases
df['Offline_Engagement'] = df['NumStorePurchases'] + df['NumCatalogPurchases']

# Discount Rate: Deals per store purchase (with smoothing to avoid division by zero)
df['Discount_Rate'] = df['NumDealsPurchases'] / (df['NumStorePurchases'] + 1)

# %%
df.drop(  ['NumStorePurchases', 'NumCatalogPurchases', 'NumDealsPurchases','NumWebPurchases','NumWebVisitsMonth'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2215 entries, 0 to 2239
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Education           2215 non-null   object
#  1   Marital_Status      2215 non-null   object
#  2   Income              2215 non-null   float64
#  3   Recency             2215 non-null   int64
#  4   MntWines            2215 non-null   int64
#  5   MntGoldProds        2215 non-null   int64
#  6   Response            2215 non-null   int64
#  7   Complain            2215 non-null   int64
#  8   Age                 2215 non-null   int64
#  9   Family_Size         2215 non-null   int64
#  10  Non_veg             2215 non-null   int64
#  11  Fruit_Sweet         2215 non-null   int64
#  12  wage_earner         2215 non-null   object
#  13  total_spent         2215 non-null   int64
#  14  Online_Engagement   2215 non-null   int64
#  15  Offline_Engagement  2215 non-null   int64
#  16  Discount_Rate       2215 non-null   float64
# dtypes: float64(2), int64(12), object(3)
# memory usage: 311.5+ KB

# %% [markdown]
# ### Binning and Seg

# %%
# Age Bins: Youth, Adult, Senior
df['Age']=pd.cut(df['Age'], bins=[0, 30, 60, 100], labels=['Youth', 'Adult', 'Senior'])

# %%
df.sample(5)
# Out:
#        Education Marital_Status   Income  Recency  MntWines  MntGoldProds  \
# 270       Master        Married  35641.0       11        63            28
# 1362      Master        Married  56962.0       60       292            26
# 391   Graduation        Married  35797.0       16        27            21
# 1140  Graduation       Together  43462.0       50        90            15
# 1425  Graduation       Divorced  63693.0       63       587            54
#
#       Response  Complain     Age  Family_Size  Non_veg  Fruit_Sweet  \
# 270          1         0   Adult            1       75           12
# 1362         0         0   Adult            3       87            6
# 391          0         0   Adult            1       18            2
# 1140         0         0  Senior            2      112           23
# 1425         0         0   Adult            1      379          130
#
#              wage_earner  total_spent  Online_Engagement  Offline_Engagement  \
# 270   medium wage earner          178                 10                   5
# 1362    high wage earner          411                 13                   8
# 391   medium wage earner           68                 10                   3
# 1140  medium wage earner          240                 12                   6
# 1425    high wage earner         1150                 17                  15
#
#       Discount_Rate
# 270        0.400000
# 1362       1.166667
# 391        0.500000
# 1140       1.000000
# 1425       0.300000

# %% [markdown]
# ## Encoding

# %%
df.sample(5)
# Out:
#        Education Marital_Status   Income  Recency  MntWines  MntGoldProds  \
# 1079         PhD       Divorced  54237.0       48       267            57
# 366   Graduation       Together  41580.0       15        56             3
# 2178         PhD         Single  86857.0       96       899            40
# 1098  Graduation         Single  18358.0       49         6             4
# 105       Master        Married  62845.0        3      1099            34
#
#       Response  Complain     Age  Family_Size  Non_veg  Fruit_Sweet  \
# 1079         0         0  Senior            1       34            3
# 366          0         0   Adult            2       28            5
# 2178         1         0   Adult            0      971          204
# 1098         0         0   Adult            1       35           12
# 105          0         0  Senior            2       45            0
#
#              wage_earner  total_spent  Online_Engagement  Offline_Engagement  \
# 1079    high wage earner          361                 11                   7
# 366   medium wage earner           92                  7                   4
# 2178    high wage earner         2114                  7                  16
# 1098     low wage earner           57                 10                   4
# 105     high wage earner         1178                 11                  14
#
#       Discount_Rate
# 1079       0.666667
# 366        0.750000
# 2178       0.090909
# 1098       0.600000
# 105        1.000000

# %%
df_encoded = pd.get_dummies(df, dtype= int, drop_first=False)

# %%
df_encoded.drop('Income', axis=1, inplace=True)

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2215 entries, 0 to 2239
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Recency                         2215 non-null   int64
#  1   MntWines                        2215 non-null   int64
#  2   MntGoldProds                    2215 non-null   int64
#  3   Response                        2215 non-null   int64
#  4   Complain                        2215 non-null   int64
#  5   Family_Size                     2215 non-null   int64
#  6   Non_veg                         2215 non-null   int64
#  7   Fruit_Sweet                     2215 non-null   int64
#  8   total_spent                     2215 non-null   int64
#  9   Online_Engagement               2215 non-null   int64
#  10  Offline_Engagement              2215 non-null   int64
#  11  Discount_Rate                   2215 non-null   float64
#  12  Education_2n Cycle              2215 non-null   int64
#  13  Education_Basic                 2215 non-null   int64
#  14  Education_Graduation            2215 non-null   int64
#  15  Education_Master                2215 non-null   int64
#  16  Education_PhD                   2215 non-null   int64
#  17  Marital_Status_Absurd           2215 non-null   int64
#  18  Marital_Status_Alone            2215 non-null   int64
#  19  Marital_Status_Divorced         2215 non-null   int64
#  20  Marital_Status_Married          2215 non-null   int64
#  21  Marital_Status_Single           2215 non-null   int64
#  22  Marital_Status_Together         2215 non-null   int64
#  23  Marital_Status_Widow            2215 non-null   int64
#  24  Marital_Status_YOLO             2215 non-null   int64
#  25  Age_Youth                       2215 non-null   int64
#  26  Age_Adult                       2215 non-null   int64
#  27  Age_Senior                      2215 non-null   int64
#  28  wage_earner_high wage earner    2215 non-null   int64
#  29  wage_earner_low wage earner     2215 non-null   int64
#  30  wage_earner_medium wage earner  2215 non-null   int64
# dtypes: float64(1), int64(30)
# memory usage: 553.8 KB

# %%
df_encoded.sample(5)
# Out:
#       Recency  MntWines  MntGoldProds  Response  Complain  Family_Size  \
# 245        10         9             2         0         0            2
# 1927       85       145             4         0         0            2
# 2053       91        43            61         0         0            1
# 1696       75        14             1         0         0            1
# 1423       63        81             0         0         0            1
#
#       Non_veg  Fruit_Sweet  total_spent  Online_Engagement  ...  \
# 245         7            4           22                  8  ...
# 1927       63           15          227                 11  ...
# 2053       52           27          183                  6  ...
# 1696        9            2           26                 11  ...
# 1423       33            2          116                  3  ...
#
#       Marital_Status_Single  Marital_Status_Together  Marital_Status_Widow  \
# 245                       0                        1                     0
# 1927                      0                        1                     0
# 2053                      0                        0                     0
# 1696                      1                        0                     0
# 1423                      0                        1                     0
#
#       Marital_Status_YOLO  Age_Youth  Age_Adult  Age_Senior  \
# 245                     0          0          1           0
# 1927                    0          0          0           1
# 2053                    0          0          1           0
# 1696                    0          0          1           0
# 1423                    0          0          1           0
#
#       wage_earner_high wage earner  wage_earner_low wage earner  \
# 245                              0                            1
# 1927                             1                            0
# 2053                             0                            0
# 1696                             0                            1
# 1423                             0                            0
#
#       wage_earner_medium wage earner
# 245                                0
# 1927                               0
# 2053                               1
# 1696                               0
# 1423                               1
#
# [5 rows x 31 columns]

# %%
# full correlation table
df_encoded.corr().style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_f63f8_row0_col0, #T_f63f8_row1_col1, #T_f63f8_row2_col2, #T_f63f8_row3_col3, #T_f63f8_row4_col4, #T_f63f8_row5_col5, #T_f63f8_row6_col6, #T_f63f8_row7_col7, #T_f63f8_row8_col8, #T_f63f8_row9_col9, #T_f63f8_row10_col10, #T_f63f8_row11_col11, #T_f63f8_row12_col12, #T_f63f8_row13_col13, #T_f63f8_row14_col14, #T_f63f8_row15_col15, #T_f63f8_row16_col16, #T_f63f8_row17_col17, #T_f63f8_row18_col18, #T_f63f8_row19_col19, #T_f63f8_row20_col20, #T_f63f8_row21_col21, #T_f63f8_row22_col22, #T_f63f8_row23_col23, #T_f63f8_row24_col24, #T_f63f8_row25_col25, #T_f63f8_row26_col26, #T_f63f8_row27_col27, #T_f63f8_row28_col28, #T_f63f8_row29_col29, #T_f63f8_row30_col30 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_f63f8_row0_col1, #T_f63f8_row3_col30, #T_f63f8_row4_col10, #T_f63f8_row5_col22, #T_f63f8_row12_col7, #T_f63f8_row12_col28, #T_f63f8_row15_col8, #T_f63f8_row17_col16, #T_f63f8_row18_col14, #T_f63f8_row19_col8, #T_f63f8_row21_col8, #T_f63f8_row21_col28, #T_f63f8_row22_col8, #T_f63f8_row23_col7, #T_f63f8_row23_col14, #T_f63f8_row23_col29 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_f63f8_row0_
{
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_f63f8_row0_col26, #T_f63f8_row11_col5, #T_f63f8_row24_col27 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_f63f8_row0_col27, #T_f63f8_row3_col8, #T_f63f8_row4_col27, #T_f63f8_row9_col26, #T_f63f8_row24_col26 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_f63f8_row0_col28, #T_f63f8_row3_col21, #T_f63f8_row4_col14, #T_f63f8_row5_col16, #T_f63f8_row9_col10, #T_f63f8_row16_col5, #T_f63f8_row17_col6, #T_f63f8_row17_col10, #T_f63f8_row18_col5, #T_f63f8_row18_col29, #T_f63f8_row18_col30, #T_f63f8_row21_col6, #T_f63f8_row26_col30 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_f63f8_row0_col29, #T_f63f8_row17_col8, #T_f63f8_row17_col29, #T_f63f8_row17_col30, #T_f63f8_row18_col16, #T_f63f8_row20_col16, #T_f63f8_row24_col29, #T_f63f8_row25_col6, #T_f63f8_row26_col5, #T_f63f8_row30_col15 {
#   background-color: #2e6d8e;
#   co

# %% [markdown]
# ## train test split

# %%
x=df_encoded.drop('Response',axis=1)
y=df_encoded['Response']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Smote

# %%
from imblearn.over_sampling import BorderlineSMOTE

# Borderline-SMOTE
bsmote = BorderlineSMOTE(random_state=42)
x_res_bsmote, y_res_bsmote = bsmote.fit_resample(X_train, y_train)

# %% [markdown]
# # Model Training

# %%
# Step 1: Define a function for model training and evaluation
def evaluate_model(model, X_train, X_test, y_train, y_test, threshold, verbose=True, shap_analysis=False, sample_weight=None):
    # Train the model
    model.fit(X_train, y_train, sample_weight=sample_weight)
    thresholds = np.arange(0.3, 0.6, 0.05)
    # Predict probabilities and apply threshold
    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob >= threshold).astype(int)

    # Metrics
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)

    if verbose:
        print(f" Threshold: {threshold}")
        print(" Accuracy:", round(accuracy, 4))
        print(" F1 Score:", round(f1, 4))
        print(" AUC Score:", round(auc, 4))
        print(" Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
        print(" Classification Report:\n", classification_report(y_test, y_pred))

# %% [markdown]
# ## Adaboost

# %%
# Step 1: Use GridSearchCV for hyperparameter tuning
grid=dict()
grid['n_estimators'] = [10,50,80,100]
grid['learning_rate'] = [0.0001,0.001,0.01,0.1,1.0]
grid_search = GridSearchCV(AdaBoostClassifier(), param_grid=grid, scoring='accuracy', n_jobs=-1, cv=10)
#grid_result = grid_search.fit(df_encoded.drop('Response', axis=1), df_encoded['Response']) # Use df_encoded as it contains the encoded data
grid_result = grid_search.fit(x_res_bsmote,y_res_bsmote)

# %%
best_params = grid_result.best_params_
print("best %f using %s"% (grid_result.best_score_, grid_result.best_params_))
# Out:
# best 0.873891 using {'learning_rate': 1.0, 'n_estimators': 100}

# %%
# step 2: Model training
sample_weights = np.where(y_res_bsmote == 1, 5, 1)
abc = AdaBoostClassifier(learning_rate=best_params['learning_rate'], n_estimators=best_params['n_estimators'])

# %%
thresholds = np.arange(0.3, 0.6, 0.05)
for t in thresholds:
    print(f"\nThreshold: {t}")
    evaluate_model(abc, x_res_bsmote, X_test, y_res_bsmote, y_test, threshold=t, verbose=True, shap_analysis=False)
# Out:
# Threshold: 0.3
#  Threshold: 0.3
#  Accuracy: 0.1422
#  F1 Score: 0.249
#  AUC Score: 0.839
#  Confusion Matrix:
#  [[  0 380]
#  [  0  63]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       380
#            1       0.14      1.00      0.25        63
#
#     accuracy                           0.14       443
#    macro avg       0.07      0.50      0.12       443
# weighted avg       0.02      0.14      0.04       443
#
#
# Threshold: 0.35
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  Threshold: 0.35
#  Accuracy: 0.1422
#  F1 Score: 0.249
#  AUC Score: 0.839
#  Confusion Matrix:
#  [[  0 380]
#  [  0  63]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       380
#            1       0.14      1.00      0.25        63
#
#     accuracy                           0.14       443
#    macro avg       0.07      0.50      0.12       443
# weighted avg       0.02      0.14      0.04       443
#
#
# Threshold: 0.39999999999999997
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  Threshold: 0.39999999999999997
#  Accuracy: 0.2777
#  F1 Score: 0.2825
#  AUC Score: 0.839
#  Confusion Matrix:
#  [[ 60 320]
#  [  0  63]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.16      0.27       380
#            1       0.16      1.00      0.28        63
#
#     accuracy                           0.28       443
#    macro avg       0.58      0.58      0.28       443
# weighted avg       0.88      0.28      0.27       443
#
#
# Threshold: 0.44999999999999996
#  Threshold: 0.44999999999999996
#  Accuracy: 0.6185
#  F1 Score: 0.4111
#  AUC Score: 0.839
#  Confusion Matrix:
#  [[215 165]
#  [  4  59]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.57      0.72       380
#            1       0.26      0.94      0.41        63
#
#     accuracy                           0.62       443
#    macro avg       0.62      0.75      0.56       443
# weighted avg       0.88      0.62      0.67       443
#
#
# Threshold: 0.49999999999999994
#  Threshold: 0.49999999999999994
#  Accuracy: 0.833
#  F1 Score: 0.4932
#  AUC Score: 0.839
#  Confusion Matrix:
#  [[333  47]
#  [ 27  36]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       380
#            1       0.43      0.57      0.49        63
#
#     accuracy                           0.83       443
#    macro avg       0.68      0.72      0.70       443
# weighted avg       0.86      0.83      0.84       443
#
#
# Threshold: 0.5499999999999999
#  Threshold: 0.5499999999999999
#  Accuracy: 0.8646
#  F1 Score: 0.1429
#  AUC Score: 0.839
#  Confusion Matrix:
#  [[378   2]
#  [ 58   5]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93       380
#            1       0.71      0.08      0.14        63
#
#     accuracy                           0.86       443
#    macro avg       0.79      0.54      0.53       443
# weighted avg       0.85      0.86      0.82       443

# %%
evaluate_model(abc, x_res_bsmote, X_test, y_res_bsmote, y_test, threshold=0.55, sample_weight=sample_weights)
# Out:
#  Threshold: 0.55
#  Accuracy: 0.8691
#  F1 Score: 0.5397
#  AUC Score: 0.8382
#  Confusion Matrix:
#  [[351  29]
#  [ 29  34]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       380
#            1       0.54      0.54      0.54        63
#
#     accuracy                           0.87       443
#    macro avg       0.73      0.73      0.73       443
# weighted avg       0.87      0.87      0.87       443

# %% [markdown]
# ##  Gradient Boosting

# %%
# Step 1: Use RandomizedSearchCV for hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV
import scipy.stats as stats
param_dist = {
    'learning_rate': stats.uniform(0.01, 0.2),
    'n_estimators': stats.randint(50, 300),
    'max_depth': stats.randint(3, 6),
    'min_samples_split': stats.randint(2, 10),
    'min_samples_leaf': stats.randint(1, 5),
    'subsample': stats.uniform(0.6, 0.4)
}

random_search = RandomizedSearchCV(
   GradientBoostingClassifier(random_state=42),
    param_distributions=param_dist,
    n_iter=50,
    scoring='f1',
    verbose=2,
    n_jobs=-1,
    random_state=42
)

# Fit on your resampled data
random_search.fit(x_res_bsmote, y_res_bsmote)

print("Best params found:", random_search.best_params_)
print("Best F1 score:", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best params found: {'learning_rate': np.float64(0.13022300234864176), 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 51, 'subsample': np.float64(0.8887995089067299)}
# Best F1 score: 0.8699917961468563

# %%
sample_weights = np.where(y_res_bsmote == 1, 5, 1)
gbc = GradientBoostingClassifier(learning_rate=random_search.best_params_['learning_rate'], n_estimators=random_search.best_params_['n_estimators'],random_state=42)

# %%
thresholds = np.arange(0.3, 0.6, 0.05)
for t in thresholds:
    print(f"\nThreshold: {t}")
    evaluate_model(gbc, x_res_bsmote, X_test, y_res_bsmote, y_test, threshold=t, verbose=True, shap_analysis=False)
# Out:
# Threshold: 0.3
#  Threshold: 0.3
#  Accuracy: 0.781
#  F1 Score: 0.4974
#  AUC Score: 0.8651
#  Confusion Matrix:
#  [[298  82]
#  [ 15  48]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.78      0.86       380
#            1       0.37      0.76      0.50        63
#
#     accuracy                           0.78       443
#    macro avg       0.66      0.77      0.68       443
# weighted avg       0.87      0.78      0.81       443
#
#
# Threshold: 0.35
#  Threshold: 0.35
#  Accuracy: 0.8036
#  F1 Score: 0.5029
#  AUC Score: 0.8651
#  Confusion Matrix:
#  [[312  68]
#  [ 19  44]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88       380
#            1       0.39      0.70      0.50        63
#
#     accuracy                           0.80       443
#    macro avg       0.67      0.76      0.69       443
# weighted avg       0.86      0.80      0.82       443
#
#
# Threshold: 0.39999999999999997
#  Threshold: 0.39999999999999997
#  Accuracy: 0.8217
#  F1 Score: 0.5093
#  AUC Score: 0.8651
#  Confusion Matrix:
#  [[323  57]
#  [ 22  41]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.85      0.89       380
#            1       0.42      0.65      0.51        63
#
#     accuracy                           0.82       443
#    macro avg       0.68      0.75      0.70       443
# weighted avg       0.86      0.82      0.84       443
#
#
# Threshold: 0.44999999999999996
#  Threshold: 0.44999999999999996
#  Accuracy: 0.8465
#  F1 Score: 0.5278
#  AUC Score: 0.8651
#  Confusion Matrix:
#  [[337  43]
#  [ 25  38]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       380
#            1       0.47      0.60      0.53        63
#
#     accuracy                           0.85       443
#    macro avg       0.70      0.75      0.72       443
# weighted avg       0.87      0.85      0.85       443
#
#
# Threshold: 0.49999999999999994
#  Threshold: 0.49999999999999994
#  Accuracy: 0.8533
#  F1 Score: 0.5185
#  AUC Score: 0.8651
#  Confusion Matrix:
#  [[343  37]
#  [ 28  35]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       380
#            1       0.49      0.56      0.52        63
#
#     accuracy                           0.85       443
#    macro avg       0.71      0.73      0.72       443
# weighted avg       0.86      0.85      0.86       443
#
#
# Threshold: 0.5499999999999999
#  Threshold: 0.5499999999999999
#  Accuracy: 0.8804
#  F1 Score: 0.5138
#  AUC Score: 0.8651
#  Confusion Matrix:
#  [[362  18]
#  [ 35  28]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       380
#            1       0.61      0.44      0.51        63
#
#     accuracy                           0.88       443
#    macro avg       0.76      0.70      0.72       443
# weighted avg       0.87      0.88      0.87       443

# %%
evaluate_model(gbc, x_res_bsmote, X_test, y_res_bsmote, y_test, threshold=.5)
# Out:
#  Threshold: 0.5
#  Accuracy: 0.8533
#  F1 Score: 0.5185
#  AUC Score: 0.8651
#  Confusion Matrix:
#  [[343  37]
#  [ 28  35]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       380
#            1       0.49      0.56      0.52        63
#
#     accuracy                           0.85       443
#    macro avg       0.71      0.73      0.72       443
# weighted avg       0.86      0.85      0.86       443

# %% [markdown]
# ## XGboost

# %%
pip install --upgrade xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.27.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.2)

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score

# %% [markdown]
# ### Optuna

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.0)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 19.6 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.5.0

# %%
scale_pos_weight = len(y_res_bsmote[y_res_bsmote == 0]) / len(y_res_bsmote[y_res_bsmote == 1])

# %%
import optuna
import xgboost as xgb
from sklearn.model_selection import cross_val_score, StratifiedKFold

def objective(trial):
    params = {
        "objective": "binary:logistic",
        "eval_metric": "logloss",
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 1),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 5.0),    # L1 regularization
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 5.0),  # L2 regularization
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "scale_pos_weight": trial.suggest_float("scale_pos_weight",1,10)
    }

    model = xgb.XGBClassifier(**params, use_label_encoder=False)
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    score = cross_val_score(model, x_res_bsmote, y_res_bsmote, cv=cv, scoring="roc_auc").mean()
    return score
# Print the best parameters
print("Best trial:")
trial = study.best_trial

print(f"  AUC Score: {trial.value}")
print("  Best Parameters:")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# Best trial:
#   AUC Score: 0.9773586665657374
#   Best Parameters:
#     min_split_gain: 0.07646682852874616
#     n_estimators: 271
#     max_depth: 7
#     learning_rate: 0.18363738020714054
#     subsample: 0.962470109812558
#     colsample_bytree: 0.8234167297704639
#     reg_alpha: 0.22756370455174757
#     reg_lambda: 0.5162571767968601
#     min_child_samples: 2
#     scale_pos_weight: 2.9803555139837083

# %%
study = optuna.create_study(direction="maximize")  # For metrics like ROC-AUC or F1
study.optimize(objective, n_trials=50)             # n_trials: number of parameter sets to try

print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# [I 2025-10-28 16:26:21,946] A new study created in memory with name: no-name-d881966d-bfde-4d95-83dd-8b1fa3093ea6
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:22] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:22] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:22] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-10-28 16:26:23,148] Trial 0 finished with value: 0.9705165318066462 and parameters: {'n_estimators': 640, 'max_depth': 7, 'learning_rate': 0.2748071773661982, 'subsample': 0.780759791574643, 'colsample_bytree': 0.9507462383280265, 'gamma': 0.643859088921076, 'reg_alpha': 4.85428488619319, 'reg_lambda': 3.1377751026801413, 'min_child_weight': 9, 'scale_pos_weight': 6.354036347881882}. Best is trial 0 with value: 0.9705165318066462.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-10-28 16:26:23,852] Trial 1 finished with value: 0.9704535466658166 and parameters: {'n_estimators': 311, 'max_depth': 4, 'learning_rate': 0.063816711408639, 'subsample': 0.6900725441750386, 'colsample_bytree': 0.6973800862701571, 'gamma': 0.2678087569816999, 'reg_alpha': 3.8378998527468577, 'reg_lambda': 4.9870440297758165, 'min_child_weight': 6, 'scale_pos_weight': 3.1357893487251363}. Best is trial 0 with value: 0.9705165318066462.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:24] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:24] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-10-28 16:26:24,844] Trial 2 finished with value: 0.9734750060756729 and parameters: {'n_estimators': 791, 'max_depth': 9, 'learning_rate': 0.2663337622539406, 'subsample': 0.8645046113031145, 'colsample_bytree': 0.603462930071192, 'gamma': 0.17399853117437336, 'reg_alpha': 3.921205867161735, 'reg_lambda': 1.366869345781549, 'min_child_weight': 1, 'scale_pos_weight': 1.0164824823474348}. Best is trial 2 with value: 0.9734750060756729.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:24] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:26] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-10-28 16:26:27,236] Trial 3 finished with value: 0.9732879762763229 and parameters: {'n_estimators': 918, 'max_depth': 9, 'learning_rate': 0.0415056307713512, 'subsample': 0.6409052909591161, 'colsample_bytree': 0.942009309168532, 'gamma': 0.4922067168649248, 'reg_alpha': 0.6502400240380124, 'reg_lambda': 0.0012844625326169368, 'min_child_weight': 10, 'scale_pos_weight': 7.966454079189106}. Best is trial 2 with value: 0.9734750060756729.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:26:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-10-28 16:26
WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:27:44] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:27:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-10-28 16:27:45,825] Trial 48 finished with value: 0.9735091387418112 and parameters: {'n_estimators': 989, 'max_depth': 4, 'learning_rate': 0.14175901462844226, 'subsample': 0.6579568106258276, 'colsample_bytree': 0.7254297596114454, 'gamma': 0.44200625596698206, 'reg_alpha': 1.2588887882751318, 'reg_lambda': 0.0034842627470373574, 'min_child_weight': 4, 'scale_pos_weight': 9.289423991841876}. Best is trial 23 with value: 0.9772104732650467.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:27:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:27:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:27:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-10-28 16:27:47,068] Trial 49 finished with value: 0.9761195161241057 and parameters: {'n_estimators': 390, 'max_depth': 9, 'learning_rate': 0.09535519761446211, 'subsample': 0.8253782518566274, 'colsample_bytree': 0.8168815905299328, 'gamma': 0.26959134412079944, 'reg_alpha': 2.9193614833214134, 'reg_lambda': 3.1938450698762697, 'min_child_weight': 2, 'scale_pos_weight': 5.874633195639299}. Best is trial 23 with value: 0.9772104732650467.
# Best hyperparameters: {'n_estimators': 563, 'max_depth': 7, 'learning_rate': 0.08595303049817397, 'subsample': 0.9607136876444806, 'colsample_bytree': 0.7803454477629205, 'gamma': 0.22718511401734476, 'reg_alpha': 2.00655763701374, 'reg_lambda': 0.04108120144714189, 'min_child_weight': 1, 'scale_pos_weight': 7.253384630053984}
# Best score: 0.9772104732650467

# %%
best_params = study.best_params
xgb_model = xgb.XGBClassifier(**best_params, use_label_encoder=False, base_score=0.5)

# %%
thresholds = np.arange(0.5, 1, 0.05)
for t in thresholds:
    print(f"\nThreshold: {t}")
    evaluate_model(xgb_model, x_res_bsmote, X_test, y_res_bsmote, y_test, threshold=t, verbose=True, shap_analysis=False)
# Out:
# Threshold: 0.5
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:32:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.5
#  Accuracy: 0.8284
#  F1 Score: 0.5
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[329  51]
#  [ 25  38]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       380
#            1       0.43      0.60      0.50        63
#
#     accuracy                           0.83       443
#    macro avg       0.68      0.73      0.70       443
# weighted avg       0.86      0.83      0.84       443
#
#
# Threshold: 0.55
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:32:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.55
#  Accuracy: 0.8488
#  F1 Score: 0.5315
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[338  42]
#  [ 25  38]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       380
#            1       0.47      0.60      0.53        63
#
#     accuracy                           0.85       443
#    macro avg       0.70      0.75      0.72       443
# weighted avg       0.87      0.85      0.86       443
#
#
# Threshold: 0.6000000000000001
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:32:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.6000000000000001
#  Accuracy: 0.8442
#  F1 Score: 0.5106
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[338  42]
#  [ 27  36]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       380
#            1       0.46      0.57      0.51        63
#
#     accuracy                           0.84       443
#    macro avg       0.69      0.73      0.71       443
# weighted avg       0.86      0.84      0.85       443
#
#
# Threshold: 0.6500000000000001
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:32:10] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.6500000000000001
#  Accuracy: 0.86
#  F1 Score: 0.5373
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[345  35]
#  [ 27  36]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       380
#            1       0.51      0.57      0.54        63
#
#     accuracy                           0.86       443
#    macro avg       0.72      0.74      0.73       443
# weighted avg       0.87      0.86      0.86       443
#
#
# Threshold: 0.7000000000000002
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:32:10] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.7000000000000002
#  Accuracy: 0.8736
#  F1 Score: 0.5484
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[353  27]
#  [ 29  34]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93       380
#            1       0.56      0.54      0.55        63
#
#     accuracy                           0.87       443
#    macro avg       0.74      0.73      0.74       443
# weighted avg       0.87      0.87      0.87       443
#
#
# Threshold: 0.7500000000000002
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:32:11] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.7500000000000002
#  Accuracy: 0.8804
#  F1 Score: 0.547
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[358  22]
#  [ 31  32]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       380
#            1       0.59      0.51      0.55        63
#
#     accuracy                           0.88       443
#    macro avg       0.76      0.73      0.74       443
# weighted avg       0.87      0.88      0.88       443
#
#
# Threshold: 0.8000000000000003
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:32:11] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.8000000000000003
#  Accuracy: 0.8871
#  F1 Score: 0.537
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[364  16]
#  [ 34  29]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94       380
#            1       0.64      0.46      0.54        63
#
#     accuracy                           0.89       443
#    macro avg       0.78      0.71      0.74       443
# weighted avg       0.88      0.89      0.88       443
#
#
# Threshold: 0.8500000000000003
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:32:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.8500000000000003
#  Accuracy: 0.8849
#  F1 Score: 0.495
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[367  13]
#  [ 38  25]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       380
#            1       0.66      0.40      0.50        63
#
#     accuracy                           0.88       443
#    macro avg       0.78      0.68      0.72       443
# weighted avg       0.87      0.88      0.87       443
#
#
# Threshold: 0.9000000000000004
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:32:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.9000000000000004
#  Accuracy: 0.8916
#  F1 Score: 0.4894
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[372   8]
#  [ 40  23]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       380
#            1       0.74      0.37      0.49        63
#
#     accuracy                           0.89       443
#    macro avg       0.82      0.67      0.71       443
# weighted avg       0.88      0.89      0.88       443
#
#
# Threshold: 0.9500000000000004
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:32:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.9500000000000004
#  Accuracy: 0.8849
#  F1 Score: 0.3855
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[376   4]
#  [ 47  16]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       380
#            1       0.80      0.25      0.39        63
#
#     accuracy                           0.88       443
#    macro avg       0.84      0.62      0.66       443
# weighted avg       0.88      0.88      0.86       443

# %%
evaluate_model(xgb_model, x_res_bsmote, X_test, y_res_bsmote, y_test, threshold=0.75)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [17:23:15] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  Threshold: 0.75
#  Accuracy: 0.8804
#  F1 Score: 0.547
#  AUC Score: 0.882
#  Confusion Matrix:
#  [[358  22]
#  [ 31  32]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       380
#            1       0.59      0.51      0.55        63
#
#     accuracy                           0.88       443
#    macro avg       0.76      0.73      0.74       443
# weighted avg       0.87      0.88      0.88       443

# %% [markdown]
# ## LightGM

# %%
import optuna
import lightgbm as lgb
from sklearn.model_selection import cross_val_score, StratifiedKFold


def objective(trial):
    params = {
        "objective": "binary",
        # LightGBM does not accept "gamma"; instead, consider 'min_split_gain'
        "min_split_gain": trial.suggest_float("min_split_gain", 0.0, 1.0),
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 5.0),    # L1
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 5.0),  # L2
        "min_child_samples": trial.suggest_int("min_child_samples", 1, 20),  # replaces min_child_weight
        "scale_pos_weight": trial.suggest_float("scale_pos_weight", 1, 10),
        "verbosity": -1
    }

    model = lgb.LGBMClassifier(**params)
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    score = cross_val_score(model, x_res_bsmote, y_res_bsmote, cv=cv, scoring="roc_auc").mean()
    return score

# %%
study = optuna.create_study(direction="maximize")  # For metrics like ROC-AUC or F1
study.optimize(objective, n_trials=50)             # n_trials: number of parameter sets to try

print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# [I 2025-10-28 17:00:31,395] A new study created in memory with name: no-name-bd265e49-508d-416b-a7e9-0d3415612e6b
# [I 2025-10-28 17:00:31,799] Trial 0 finished with value: 0.9747531178494641 and parameters: {'min_split_gain': 0.7430033504741749, 'n_estimators': 652, 'max_depth': 7, 'learning_rate': 0.2703120887469505, 'subsample': 0.966492431361405, 'colsample_bytree': 0.6165714905863933, 'reg_alpha': 0.9918757194934308, 'reg_lambda': 2.1209291734192854, 'min_child_samples': 18, 'scale_pos_weight': 9.44305149890822}. Best is trial 0 with value: 0.9747531178494641.
. Best is trial 16 with value: 0.9770046307916435.
# [I 2025-10-28 17:00:50,041] Trial 39 finished with value: 0.9755937492944916 and parameters: {'min_split_gain': 0.15721449380632602, 'n_estimators': 228, 'max_depth': 4, 'learning_rate': 0.22974960993414195, 'subsample': 0.9387431790585299, 'colsample_bytree': 0.7009630260023163, 'reg_alpha': 0.34273164573342496, 'reg_lambda': 0.01229332430673602, 'min_child_samples': 14, 'scale_pos_weight': 1.877431792521325}. Best is trial 16 with value: 0.9770046307916435.
# [I 2025-10-28 17:00:50,266] Trial 40 finished with value: 0.9745405317110291 and parameters: {'min_split_gain': 0.07544706711898422, 'n_estimators': 105, 'max_depth': 5, 'learning_rate': 0.28576510576035496, 'subsample': 0.9136716188394535, 'colsample_bytree': 0.7235265535574874, 'reg_alpha': 1.0033683166121579, 'reg_lambda': 0.5971878056213058, 'min_child_samples': 20, 'scale_pos_weight': 4.137366113901082}. Best is trial 16 with value: 0.9770046307916435.
# [I 2025-10-28 17:00:50,525] Trial 41 finished with value: 0.9759543560915428 and parameters: {'min_split_gain': 0.02330709854040429, 'n_estimators': 180, 'max_depth': 6, 'learning_rate': 0.2558131527111794, 'subsample': 0.9956273990090264, 'colsample_bytree': 0.7567174630583177, 'reg_alpha': 2.238865063092545, 'reg_lambda': 0.3284598034294892, 'min_child_samples': 5, 'scale_pos_weight': 1.9375846796542189}. Best is trial 16 with value: 0.9770046307916435.
# [I 2025-10-28 17:00:51,000] Trial 42 finished with value: 0.9772967464937059 and parameters: {'min_split_gain': 0.003455427335227912, 'n_estimators': 293, 'max_depth': 7, 'learning_rate': 0.2008994959259061, 'subsample': 0.9508734242765134, 'colsample_bytree': 0.7755657445375722, 'reg_alpha': 0.6472354698334316, 'reg_lambda': 0.48831784027790626, 'min_child_samples': 3, 'scale_pos_weight': 2.911620267586123}. Best is trial 42 with value: 0.9772967464937059.
# [I 2025-10-28 17:00:51,386] Trial 43 finished with value: 0.9769367930805056 and parameters: {'min_split_gain': 0.046199541994438924, 'n_estimators': 274, 'max_depth': 6, 'learning_rate': 0.1862429143506817, 'subsample': 0.9565327633070696, 'colsample_bytree': 0.8250437330741786, 'reg_alpha': 0.5715367728289596, 'reg_lambda': 0.544253363238697, 'min_child_samples': 3, 'scale_pos_weight': 2.9223001680188183}. Best is trial 42 with value: 0.9772967464937059.
# [I 2025-10-28 17:00:51,795] Trial 44 finished with value: 0.9773586665657374 and parameters: {'min_split_gain': 0.07646682852874616, 'n_estimators': 271, 'max_depth': 7, 'learning_rate': 0.18363738020714054, 'subsample': 0.962470109812558, 'colsample_bytree': 0.8234167297704639, 'reg_alpha': 0.22756370455174757, 'reg_lambda': 0.5162571767968601, 'min_child_samples': 2, 'scale_pos_weight': 2.9803555139837083}. Best is trial 44 with value: 0.9773586665657374.
# [I 2025-10-28 17:00:52,238] Trial 45 finished with value: 0.9751937747923979 and parameters: {'min_split_gain': 0.06576175630888298, 'n_estimators': 358, 'max_depth': 8, 'learning_rate': 0.15371440476156722, 'subsample': 0.976053669539963, 'colsample_bytree': 0.8653763660770075, 'reg_alpha': 1.369484903990347, 'reg_lambda': 1.2478847344535788, 'min_child_samples': 2, 'scale_pos_weight': 3.215333932609166}. Best is trial 44 with value: 0.9773586665657374.
# [I 2025-10-28 17:00:52,591] Trial 46 finished with value: 0.9772029088861531 and parameters: {'min_split_gain': 0.06059431779659404, 'n_estimators': 290, 'max_depth': 5, 'learning_rate': 0.1955303809746788, 'subsample': 0.9694963285109843, 'colsample_bytree': 0.8288884613144964, 'reg_alpha': 0.795241670830446, 'reg_lambda': 0.5461828564674349, 'min_child_samples': 1, 'scale_pos_weight': 2.414506718584604}. Best is trial 44 with value: 0.9773586665657374.
# [I 2025-10-28 17:00:52,907] Trial 47 finished with value: 0.9772957451696739 and parameters: {'min_split_gain': 0.11602675070744886, 'n_estimators': 184, 'max_depth': 5, 'learning_rate': 0.17919998986062666, 'subsample': 0.964184121440198, 'colsample_bytree': 0.8233000981465812, 'reg_alpha': 0.8098690067977586, 'reg_lambda': 0.5294963390521725, 'min_child_samples': 1, 'scale_pos_weight': 2.4968328039732293}. Best is trial 44 with value: 0.9773586665657374.
# [I 2025-10-28 17:00:53,289] Trial 48 finished with value: 0.9494122453695404 and parameters: {'min_split_gain': 0.16078021954750693, 'n_estimators': 166, 'max_depth': 4, 'learning_rate': 0.011214034914133697, 'subsample': 0.9774813502625427, 'colsample_bytree': 0.899161419917767, 'reg_alpha': 1.7427019497590353, 'reg_lambda': 1.0925391244685274, 'min_child_samples': 1, 'scale_pos_weight': 1.0091245428976574}. Best is trial 44 with value: 0.9773586665657374.
# [I 2025-10-28 17:00:53,567] Trial 49 finished with value: 0.9750709067560156 and parameters: {'min_split_gain': 0.27055899553600954, 'n_estimators': 170, 'max_depth': 5, 'learning_rate': 0.1771087054948384, 'subsample': 0.912348414863345, 'colsample_bytree': 0.8535183802961797, 'reg_alpha': 0.8444599478006152, 'reg_lambda': 4.396739652637297, 'min_child_samples': 1, 'scale_pos_weight': 2.350490090292313}. Best is trial 44 with value: 0.9773586665657374.
# Best hyperparameters: {'min_split_gain': 0.07646682852874616, 'n_estimators': 271, 'max_depth': 7, 'learning_rate': 0.18363738020714054, 'subsample': 0.962470109812558, 'colsample_bytree': 0.8234167297704639, 'reg_alpha': 0.22756370455174757, 'reg_lambda': 0.5162571767968601, 'min_child_samples': 2, 'scale_pos_weight': 2.9803555139837083}
# Best score: 0.9773586665657374

# %%
best_params = study.best_params
Lgm = lgb.LGBMClassifier(**best_params, use_label_encoder=False, base_score=0.5)

# %%
thresholds = np.arange(0.5, 1, 0.05)
for t in thresholds:
    print(f"\nThreshold: {t}")
    evaluate_model(Lgm, x_res_bsmote, X_test, y_res_bsmote, y_test, threshold=t, verbose=True, shap_analysis=False)
# Out:
# Threshold: 0.5
#  Threshold: 0.5
#  Accuracy: 0.8736
#  F1 Score: 0.5556
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[352  28]
#  [ 28  35]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       380
#            1       0.56      0.56      0.56        63
#
#     accuracy                           0.87       443
#    macro avg       0.74      0.74      0.74       443
# weighted avg       0.87      0.87      0.87       443
#
#
# Threshold: 0.55
#  Threshold: 0.55
#  Accuracy: 0.8804
#  F1 Score: 0.5691
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[355  25]
#  [ 28  35]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       380
#            1       0.58      0.56      0.57        63
#
#     accuracy                           0.88       443
#    macro avg       0.76      0.74      0.75       443
# weighted avg       0.88      0.88      0.88       443
#
#
# Threshold: 0.6000000000000001
#  Threshold: 0.6000000000000001
#  Accuracy: 0.8826
#  F1 Score: 0.5593
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[358  22]
#  [ 30  33]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       380
#            1       0.60      0.52      0.56        63
#
#     accuracy                           0.88       443
#    macro avg       0.76      0.73      0.75       443
# weighted avg       0.88      0.88      0.88       443
#
#
# Threshold: 0.6500000000000001
#  Threshold: 0.6500000000000001
#  Accuracy: 0.8804
#  F1 Score: 0.5391
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[359  21]
#  [ 32  31]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       380
#            1       0.60      0.49      0.54        63
#
#     accuracy                           0.88       443
#    macro avg       0.76      0.72      0.74       443
# weighted avg       0.87      0.88      0.88       443
#
#
# Threshold: 0.7000000000000002
#  Threshold: 0.7000000000000002
#  Accuracy: 0.8758
#  F1 Score: 0.5045
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[360  20]
#  [ 35  28]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       380
#            1       0.58      0.44      0.50        63
#
#     accuracy                           0.88       443
#    macro avg       0.75      0.70      0.72       443
# weighted avg       0.86      0.88      0.87       443
#
#
# Threshold: 0.7500000000000002
#  Threshold: 0.7500000000000002
#  Accuracy: 0.8758
#  F1 Score: 0.4954
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[361  19]
#  [ 36  27]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       380
#            1       0.59      0.43      0.50        63
#
#     accuracy                           0.88       443
#    macro avg       0.75      0.69      0.71       443
# weighted avg       0.86      0.88      0.87       443
#
#
# Threshold: 0.8000000000000003
#  Threshold: 0.8000000000000003
#  Accuracy: 0.8826
#  F1 Score: 0.5
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[365  15]
#  [ 37  26]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       380
#            1       0.63      0.41      0.50        63
#
#     accuracy                           0.88       443
#    macro avg       0.77      0.69      0.72       443
# weighted avg       0.87      0.88      0.87       443
#
#
# Threshold: 0.8500000000000003
#  Threshold: 0.8500000000000003
#  Accuracy: 0.8894
#  F1 Score: 0.4842
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[371   9]
#  [ 40  23]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       380
#            1       0.72      0.37      0.48        63
#
#     accuracy                           0.89       443
#    macro avg       0.81      0.67      0.71       443
# weighted avg       0.88      0.89      0.87       443
#
#
# Threshold: 0.9000000000000004
#  Threshold: 0.9000000000000004
#  Accuracy: 0.8781
#  F1 Score: 0.4
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[371   9]
#  [ 45  18]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93       380
#            1       0.67      0.29      0.40        63
#
#     accuracy                           0.88       443
#    macro avg       0.78      0.63      0.67       443
# weighted avg       0.86      0.88      0.86       443
#
#
# Threshold: 0.9500000000000004
#  Threshold: 0.9500000000000004
#  Accuracy: 0.8826
#  F1 Score: 0.3659
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[376   4]
#  [ 48  15]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       380
#            1       0.79      0.24      0.37        63
#
#     accuracy                           0.88       443
#    macro avg       0.84      0.61      0.65       443
# weighted avg       0.87      0.88      0.85       443

# %%
evaluate_model(Lgm, x_res_bsmote, X_test, y_res_bsmote, y_test, threshold=0.55)
# Out:
#  Threshold: 0.55
#  Accuracy: 0.8804
#  F1 Score: 0.5691
#  AUC Score: 0.8777
#  Confusion Matrix:
#  [[355  25]
#  [ 28  35]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       380
#            1       0.58      0.56      0.57        63
#
#     accuracy                           0.88       443
#    macro avg       0.76      0.74      0.75       443
# weighted avg       0.88      0.88      0.88       443
